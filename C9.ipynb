# %% [markdown]
# <a href="https://colab.research.google.com/github/ogundipeflorence53-collab/pace/blob/main/C9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
citris_fruits = ['Orange', 'Lemon', 'Grapefruit', 'Pomelo', 'Lime']
citris_fruits[2:4]
# Out:
# ['Grapefruit', 'Pomelo']

# %%
citris_fruits[:4]
# Out:
# ['Orange', 'Lemon', 'Grapefruit', 'Pomelo']

# %%
citris_fruits[2:]
# Out:
# ['Grapefruit', 'Pomelo', 'Lime']

# %%
my_favorite_desserts = ['cheesecake', 'cake', 'cookies', 'Icecream']
my_favorite_desserts = []
my_favorite_desserts
# Out:
# []

# %%
'Pomelo' in citris_fruits
# Out:
# True

# %%
'Donuts' not in citris_fruits
# Out:
# True

# %%
my_favorite_desserts += ['Brownies', 'Muffins', 'Chocolate']
my_favorite_desserts
# Out:
# ['Brownies', 'Muffins', 'Chocolate']

# %%
'Limes' not in citris_fruits
# Out:
# True

# %%
my_favorite_desserts.append('Creme Brulee')
my_favorite_desserts
# Out:
# ['Brownies', 'Muffins', 'Chocolate', 'Creme Brulee']

# %%
my_favorite_desserts.append('Apple Pie')
my_favorite_desserts
# Out:
# ['Brownies', 'Muffins', 'Chocolate', 'Creme Brulee', 'Apple Pie']

# %%
my_favorite_desserts.remove('Muffins')
my_favorite_desserts
# Out:
# ['Brownies', 'Chocolate', 'Creme Brulee', 'Apple Pie']

# %%
del my_favorite_desserts[1]
my_favorite_desserts
# Out:
# ['Brownies', 'Creme Brulee', 'Apple Pie']

# %%
my_favorite_desserts[1] = 'Pumpkin Pie'
my_favorite_desserts
# Out:
# ['Brownies', 'Pumpkin Pie']

# %%
my_favorite_desserts[2:2] = ['Chocolate Souffle', 'Crepe Cake', 'Affogoto']
my_favorite_desserts
# Out:
# ['Brownies',
#  'Pumpkin Pie',
#  'Chocolate Souffle',
#  'Crepe Cake',
#  'Affogoto',
#  'Chocolate Souffle',
#  'Crepe Cake',
#  'Affogoto']

# %%
del my_favorite_desserts[1:]
my_favorite_desserts
# Out:
# ['Brownies']

# %%
my_favorite_desserts[1:1] = ['Pumpkin Pie']
my_favorite_desserts
# Out:
# ['Brownies', 'Pumpkin Pie']
