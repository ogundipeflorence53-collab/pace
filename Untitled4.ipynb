# %% [markdown]
# <a href="https://colab.research.google.com/github/ogundipeflorence53-collab/pace/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Area
l = int(input("length:"))
b = int(input("breadth:"))
print("Area", l * b)
# Out:
# breadth:80
# Area 4800

# %%
### perimeter of a rectangle = 2(l + w)
l = int(input("length:"))
b = int(input("breadth:"))
print("perimeter", 2 * (l + b) )
# Out:
# length:10
# breadth:5
# perimeter 30

# %%
### Area of a triangle
### Area of a circle
### speed
### Distance

# %%
### Area of a triangle = 1/2(b * h)
b = int(input("base:"))
h = int(input("height:"))
print("Area", 1/2 * (b * h))
# Out:
# base:15
# height:7
# Area 52.5

# %%
### Area of a circle = A = pi r2
r = int(input("radius:"))
print("Area", 3.14 * r * r)
# Out:
# radius:12
# Area 452.15999999999997

# %%
### speed = Distance / Time
d = int(input("distance:"))
t = int(input("time:"))
print("speed", d / t)
# Out:
# distance:20
# time:10
# speed 2.0

# %%
### Distance = speed * time
s = int(input("speed:"))
t = int(input("time:"))
print("distance", s * t)
# Out:
# speed:50
# time:25
# distance 1250

# %%
### Time = Distance / Speed
d = int(input("distance:"))
s = int(input("speed:"))
print("time", d / s)
# Out:
# distance:100
# speed:50
# time 2.0

# %%
### Area of a trapezium = 1/2 * (a + b) * h
a = int(input("a:"))
b = int(input("b:"))
h = int(input("height:"))
print("Area", 1/2 * (a + b) * h)
# Out:
# a:60
# b:30
# height:15
# Area 675.0

# %%
### Area of a square = S2
s = int(input("side:"))
print("Area", s * s)
# Out:
# side:20
# Area 400

# %%
### Area of a cylinder = 2pie rh
r = int(input("radius:"))
h = int(input("height:"))
print("Area", 2 * 3.14 * r * h)
# Out:
# radius:30
# height:15
# Area 2826.0

# %%
### Area of a rectangle = length * width
l = int(input("length:"))
w = int(input("width:"))
print("Area", l * w)
# Out:
# length:60
# width:30
# Area 1800

# %%
### Area of a parallogram = A = bh
b = int(input("base:"))
h = int(input("height:"))
print("Area", b * h)
# Out:
# base:100
# height:50
# Area 5000

# %%
### Perimeter of a triangle = p = a + b + c
a = int(input("a:"))
b = int(input("b:"))
c = int(input("c:"))
print("Perimeter", a + b + c)
# Out:
# a:100
# b:50
# c:25
# Perimeter 175

# %%
### perimeter of a circle = C = 2pie r
r = int(input("radius:"))
print("Perimeter", 2 * 3.14 * r)
# Out:
# radius:50
# Perimeter 314.0
