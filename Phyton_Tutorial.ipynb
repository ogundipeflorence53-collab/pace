# %% [markdown]
# <a href="https://colab.research.google.com/github/ogundipeflorence53-collab/pace/blob/main/Phyton_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello phyton")
# Out:
# hello phyton

# %%
print(3*4)
# Out:
# 12

# %% [markdown]
# how do you calculate222 times 444?

# %%
print(222*444)
# Out:
# 98568

# %%
print("Hi! My name is peace")
# Out:
# Hi! My name is peace

# %%
print('"You are unique just the way you are"- Npstation')
# Out:
# "You are unique just the way you are"- Npstation

# %%
Haiku ="write your haiku poem here in multiple lines"

# %%
name = 'Peace'
age = 10 + 2
print(f'Hi! my name is {name} and I am {age} years old!')
# Out:
# Hi! my name is Neha and I am 12 years old!

# %%
5**3
# Out:
# 125

# %%
5%3
# Out:
# 2

# %%
magic_number = 6**4
print(magic_number)
# Out:
# 1296

# %%
magic_number = 5**4%333+41
print(magic_number)
# Out:
# 333
